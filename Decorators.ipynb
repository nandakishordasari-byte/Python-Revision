# %%
# EX 1
def logger(func):
    def wrapper():
        print("start")
        func()
        print("end")
    return wrapper
@logger
def login():
    print("login")
login()
# Out:
# start
# login
# end

# %%
# EX 2
def logger(paytm):
    def wrapper():
        if paytm.__name__=="login":
            print("start avuthundi")
        elif paytm.__name__=="logout":
            print("logout avuthundhi")
        else:
            print("try again")
        paytm()
        print("end avuthundi") 
        return "indhumathi from kingston"
    wrapper()
@logger
def login():
    print("give login access")
def logout():
    print("give logout access")
# Out:
# start avuthundi
# give login access
# end avuthundi
