# %%
arr=[20,10,2,20,3,4]
T=20
#print(arr[3])
for i in arr:
    if i==T:
        print(f"found {i} at {arr.index(i)}")
# Out:
# found 20 at 0
# found 20 at 0

# %%
arr=[20,10,2,20,3,4]
f=0
for i in arr:
    f+=i
print(f)
# Out:
# 59

# %%
# Target doesn't exist
arr=[20,10,2,20,3,4]
T=50
F=True
for i in arr:
    if i==T:
        print(F)
    else:
        print(False)
# Out:
# False
# False
# False
# False
# False
# False

# %%
#If element doesn't exist

D = [12,3,324,23,42,3,213,23]
T = 23
F = True
for i in D:
        if i == T:
                print(F)
        F = False
print(F)
# Out:
# False
# False
# False

# %%
# Target doesn't exist
arr=[20,10,2,20,3,4]
T=10
for i in arr:
    if i%T==0:
        print(f"Found:{T} at {arr.index(i)}")
    else:
        print("Not found")
# Out:
# Found:10 at 0
# Found:10 at 1
# Not found
# Found:10 at 0
# Not found
# Not found

# %%
'''Find whether 20 exists
1. Find whether any number is greater than 20(x > 20)
2. Find whether any even number exists(x % 2 == 0)
3. Find the first negative number(x < 0)'''
